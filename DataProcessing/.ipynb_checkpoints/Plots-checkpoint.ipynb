# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from scipy.optimize import curve_fit
import numpy as np

# %% [markdown]
# # Non-Normalized Group Plots

# %%
def plotGroupAverages(func,directory,column='GroupAvgLogRT'):
    #list out the conditions
    plt.figure(figsize=(30,30))
    conditions = ['Sham','Anod','Cath','Vertex']
    os.chdir(directory)
    #find min and max
    maximum = 0
    minimum = 1e100
    length = 0
    for f in os.listdir():
        if(f.endswith('.csv')):
            df = pd.read_csv(f)
            if maximum < df[column].max():
                maximum = df[column].max()
            if minimum > df[column].min():
                minimum = df[column].min()
            if length < len(df[column].values):
                length = len(df[column].values)
    print("min,max,len")
    print(minimum,maximum,length)
    for i,c in enumerate(conditions):
        for f in os.listdir():
            if (c in f):
                #then we want to make the plot
                df = pd.read_csv(f)
                x = np.arange(1,len(df[column].values)+1,1)
                y = df[column].to_numpy()
                #Fit the curve
                popt, pcov = curve_fit(func, x[:24], y[:24])

                print(popt)
                #create a trend line
                trendline = func(x,*popt)

                plt.subplot(2,2,i+1) 
                
                
                print("min,max,len")
                print(minimum,maximum,length)
                
               
                if "control".lower() in f.lower():
                    plt.scatter(x,y,label="Control",color='blue')
                    plt.plot(x,trendline,'b--',label="Control Regression")
                else:
                    plt.scatter(x,y,label="Patient",color='red')
                    plt.plot(x,trendline,'r--',label="Patient Regression")
                
                plt.yticks(np.arange(minimum,maximum + (maximum-minimum)/length,(maximum-minimum)/length))
                plt.xticks(np.arange(1,len(df[column].values),3)) 
                plt.ylim(minimum,maximum)

                plt.grid(True)
                plt.title(c)
                plt.xlabel("Run")
                plt.ylabel(column) 
                plt.legend()
    plt.savefig("{}_plot.png".format(column))

# %% [markdown]
# ## Non-Normalized Plots

# %%
#Define a fucntion that we want to fit the data to
def func(x,y0,K,plateau):
    
    #plateau = 0
    return (y0 - plateau) * np.exp(-K * x) + plateau
directory = "/Users/adish/Documents/NYPSI and NKI Research/TDCS-SRTT/data/WrangledData/SUBJECT_RUN/subjectRunAvgs/groupAverageLogRTs"

plotGroupAverages(func,directory)
# Out:
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.68406998 0.04492551 2.46608239]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.7854028  0.03219411 2.58804579]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.68798504 0.09730982 2.53001607]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.79262021 0.06788332 2.64754396]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.71104827 0.11044248 2.50238816]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.79042607 0.1130288  2.64043717]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.77296831 0.09298372 2.66709511]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36
# [2.68540372 0.12872403 2.53266234]
# min,max,len
# 2.3768656451184347 2.7926941195568014 36

# %% [markdown]
# ## Normalized Plots

# %%
directory = "/Users/adish/Documents/NYPSI and NKI Research/TDCS-SRTT/data/NormalizedData/NormalizedWrangledData/SUBJECT_RUN/subjectRunAvgs/groupAverageLogRTs"
def normFunc(x,K,plateau):
    y0 = 0
    #plateau = 0
    return (y0 - plateau) * np.exp(-K * x) + plateau
plotGroupAverages(normFunc,directory)
# Out:
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.05863158 -0.29168583]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.04626909 -0.12032494]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.10399583 -0.23635843]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.06175185 -0.13836346]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.11357305 -0.26259433]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.11230852 -0.13730439]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.10597576 -0.13355304]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30
# [ 0.13520253 -0.21563604]
# min,max,len
# -0.2854485545988861 0.0200314467481321 30

# %% [markdown]
# ## Percent Fast Group Average Plots on Normalized Data

# %%
directory = "/Users/adish/Documents/NYPSI and NKI Research/TDCS-SRTT/data/NormalizedData/NormalizedWrangledData/SUBJECT_RUN/subjectRunAvgs/groupAverageLogRTs/PercentFastGroupAverages"
def percentFastFunc(x,plateau,k):
    return plateau * np.log(k*x)
plotGroupAverages(percentFastFunc,directory,column='GroupAvgPercentFast')
# Out:
# min,max,len
# 0.373266078184111 52.250961818944525 30
# [3.91018744 0.91895398]
# min,max,len
# 0.373266078184111 52.250961818944525 30
# [11.49087541  0.66664627]
# min,max,len
# 0.373266078184111 52.250961818944525 30
# [6.60586129 0.51190428]
# min,max,len
# 0.373266078184111 52.250961818944525 30
# [13.35293962  0.66754689]
# min,max,len
# 0.373266078184111 52.250961818944525 30
# [15.56357173  0.67536849]
# min,max,len
# 0.373266078184111 52.250961818944525 30
# [6.44738977 1.03826075]
# min,max,len
# 0.373266078184111 52.250961818944525 30
# <ipython-input-46-fe4400889452>:3: RuntimeWarning: invalid value encountered in log
#   return plateau * np.log(k*x)
# <ipython-input-46-fe4400889452>:3: RuntimeWarning: invalid value encountered in log
#   return plateau * np.log(k*x)
# <ipython-input-46-fe4400889452>:3: RuntimeWarning: invalid value encountered in log
#   return plateau * np.log(k*x)
# <ipython-input-46-fe4400889452>:3: RuntimeWarning: invalid value encountered in log
#   return plateau * np.log(k*x)
# <ipython-input-46-fe4400889452>:3: RuntimeWarning: invalid value encountered in log
#   return plateau * np.log(k*x)
# [7.17196277 0.5435401 ]
# min,max,len
# 0.373266078184111 52.250961818944525 30
# [10.66419549  1.03137192]
# min,max,len
# 0.373266078184111 52.250961818944525 30
